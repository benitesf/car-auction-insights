# %% [markdown]
# # Scraping Superbid

# %%
import pandas as pd
import json

import os

# %%
data_path = os.path.join(os.pardir, "data/raw/superbid/", "bids-2025-04-16.json")

with open(data_path, "r") as f:
    bids_data = json.load(f)

# %%
bid_labels = ["id", "name", "date", "link"]
car_auction_labels = ["id", "title", "location", "close_date", "start_date", "visits", "participants", "number_of_offers", "offer",
                      "currency", "winner", "company", "seller", "initial_offer", "brand", "model", "year_of_model",
                      "chassis", "engine", "transmission", "fuel", "plate", "traction", "year_of_production", "link_to_car_auction"]

# %%
bids_data[0]["details"][0]["car_auction_details"]["information"]
# Out:
# ['Marca: KIA',
#  'Modelo: SOLUTO',
#  'Placa: Final: 7',
#  'Año de Fabricación: 2023',
#  'Tipo de cambio: Manual',
#  'lote-01-cfi127.pdf']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data = []
for bid in bids_data[0:1]:
    data.append({

    })
# Out:
# {'name': '69° REMATE SANTANDER / 15:00 hrs.', 'date': '15/04/2025', 'link': '/evento/69-remate-santander-1500-hrs-399809?searchType=all&&pageNumber=1&pageSize=30&orderBy=lotNumber:asc;subLotNumber:asc', 'id': '69° REMATE SANTANDER / 15:00 hrs._15/04/2025', 'details': [{'link_to_car_auction': '/oferta/sedan-marca-kia-modelo-soluto-14-mt-lx-full-ano-2023-placa-7-ubicacion-lambayeque-comisaria-la-victoria-importante-no-se-emitira-boleta-y-o-factura-por-la-venta-3793456', 'car_auction_details': {'title': None, 'close_date': '15/04/2025 para 17:17:06', 'start_date': '15/04/2025 para 05:20', 'visits': 'Visitas: 338', 'participants': 'Participantes: 11', 'number_of_offers': 'Ofertar: 38', 'offer': 'OFERTA:7.350,00\xa0$', 'currency': ' (USD)', 'winner': 'GANADOR:s*****ac', 'company': 'Tienda:\xa0\xa0 Santander ', 'seller': 'Vendedor:\xa0\xa0SANTANDER', 'initial_offer': 'Oferta inicial:\xa0\xa0US$ 5.500,00', 'description': ['SEDAN', 'MARCA: KIA', 'MODELO: SOLUTO 1.4 MT - LX FULL', 'AÑO: 2024'
# ...
